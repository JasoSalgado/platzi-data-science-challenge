# %% [markdown]
# # Modules: pandas and numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Reading and showing the csv document

df = pd.read_csv('books.csv', error_bad_lines=False)
df
# Out:
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#              isbn         isbn13 language_code    num_pages  ratings_count  \
# 0      0439785960  9780439785969           eng          652        2095690
# 1      0439358078  9780439358071           eng          870        2153167
# 2      0439554896  9780439554893           eng          352           6333
# 3      043965548X  9780439655484           eng          435        2339585
# 4      0439682584  9780439682589           eng         2690          41428
# ...           ...            ...           ...          ...            ...
# 11118  1560254416  9781560254416           eng          512            156
# 11119  0140110879  9780140110876           eng          635            783
# 11120  0140131965  9780140131963           eng          415            820
# 11121  0060878827  9780060878825           eng          434            769
# 11122  8497646983  9788497646987           spa          272            113
#
#        text_reviews_count publication_date        publisher
# 0                   27591        9/16/2006  Scholastic Inc.
# 1                   29221         9/1/2004  Scholastic Inc.
# 2                     244        11/1/2003       Scholastic
# 3                   36325         5/1/2004  Scholastic Inc.
# 4                     164        9/13/2004       Scholastic
# ...                   ...              ...              ...
# 11118                  20       12/21/2004    Da Capo Press
# 11119                  56        12/1/1988    Penguin Books
# 11120                  95         8/1/1993    Penguin Books
# 11121                 139        2/27/2007             Ecco
# 11122                  12        5/28/2006    Edimat Libros
#
# [11123 rows x 12 columns]

# %% [markdown]
# # Showing the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# # Showing all table

# %%
df.describe(include='all')
# Out:
#               bookID      title         authors  average_rating        isbn  \
# count   11123.000000      11123           11123    11123.000000       11123
# unique           NaN      10348            6639             NaN       11123
# top              NaN  The Iliad  P.G. Wodehouse             NaN  0340831200
# freq             NaN          9              40             NaN           1
# mean    21310.856963        NaN             NaN        3.934075         NaN
# std     13094.727252        NaN             NaN        0.350485         NaN
# min         1.000000        NaN             NaN        0.000000         NaN
# 25%     10277.500000        NaN             NaN        3.770000         NaN
# 50%     20287.000000        NaN             NaN        3.960000         NaN
# 75%     32104.500000        NaN             NaN        4.140000         NaN
# max     45641.000000        NaN             NaN        5.000000         NaN
#
#               isbn13 language_code     num_pages  ratings_count  \
# count   1.112300e+04         11123  11123.000000   1.112300e+04
# unique           NaN            27           NaN            NaN
# top              NaN           eng           NaN            NaN
# freq             NaN          8908           NaN            NaN
# mean    9.759880e+12           NaN    336.405556   1.794285e+04
# std     4.429758e+11           NaN    241.152626   1.124992e+05
# min     8.987060e+09           NaN      0.000000   0.000000e+00
# 25%     9.780345e+12           NaN    192.000000   1.040000e+02
# 50%     9.780582e+12           NaN    299.000000   7.450000e+02
# 75%     9.780872e+12           NaN    416.000000   5.000500e+03
# max     9.790008e+12           NaN   6576.000000   4.597666e+06
#
#         text_reviews_count publication_date publisher
# count         11123.000000            11123     11123
# unique                 NaN             3679      2290
# top                    NaN        10/1/2005   Vintage
# freq                   NaN               56       318
# mean            542.048099              NaN       NaN
# std            2576.619589              NaN       NaN
# min               0.000000              NaN       NaN
# 25%               9.000000              NaN       NaN
# 50%              47.000000              NaN       NaN
# 75%             238.000000              NaN       NaN
# max           94265.000000              NaN       NaN

# %% [markdown]
# # ¿Qué libro obtuvo el mayor número de reviews?

# %%
# We order the table
df.sort_values('text_reviews_count', ascending=False)
(df.head(10))
# Out:
#        bookID                                              title  \
# 10336   41865                            Twilight (Twilight  #1)
# 5270    19063                                     The Book Thief
# 1069     3636                          The Giver (The Giver  #1)
# 284       865                                      The Alchemist
# 10700   43641                                Water for Elephants
# 7309    28187  The Lightning Thief (Percy Jackson and the Oly...
# 5407    19501                                    Eat  Pray  Love
# 2060     7445                                   The Glass Castle
# 1462     5107                             The Catcher in the Rye
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                                         authors  average_rating        isbn  \
# 10336                           Stephenie Meyer            3.59  0316015849
# 5270          Markus Zusak/Cao Xuân Việt Khương            4.37  0375831002
# 1069                                 Lois Lowry            4.13  0385732554
# 284    Paulo Coelho/Alan R. Clarke/Özdemir İnce            3.86  0061122416
# 10700                                Sara Gruen            4.09  1565125606
# 7309                               Rick Riordan            4.25  0786838655
# 5407                          Elizabeth Gilbert            3.55  0143038419
# 2060                            Jeannette Walls            4.27  074324754X
# 1462                              J.D. Salinger            3.80  0316769177
# 3                    J.K. Rowling/Mary GrandPré            4.56  043965548X
#
#               isbn13 language_code    num_pages  ratings_count  \
# 10336  9780316015844           eng          501        4597666
# 5270   9780375831003           eng          552        1516367
# 1069   9780385732550           eng          208        1585589
# 284    9780061122415           eng          197        1631221
# 10700  9781565125605           eng          335        1260027
# 7309   9780786838653           eng          375        1766725
# 5407   9780143038412           eng          368        1362264
# 2060   9780743247542           eng          288         808656
# 1462   9780316769174           eng          277        2457092
# 3      9780439655484           eng          435        2339585
#
#        text_reviews_count publication_date                  publisher
# 10336               94265         9/6/2006  Little  Brown and Company
# 5270                86881        3/14/2006            Alfred A. Knopf
# 1069                56604        1/24/2006                      Ember
# 284                 55843         5/1/1993              HarperCollins
# 10700               52759         5/1/2007            Algonquin Books
# 7309                47951         3/1/2006      Disney Hyperion Books
# 5407                47620         2/1/2007            Riverhead Books
# 2060                46176        1/17/2006                   Scribner
# 1462                43499        1/30/2001             Back Bay Books
# 3                   36325         5/1/2004            Scholastic Inc.

# %%
# It returns the first and last row and columns title, authors and text_reviewscount

df.iloc[[0, 11122], [1, 2, 9]]
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 11122                        Las aventuras de Tom Sawyer
#
#                           authors  text_reviews_count
# 0      J.K. Rowling/Mary GrandPré               27591
# 11122                  Mark Twain                  12

# %% [markdown]
# # ¿Qué libro tiene mejor puntuación?

# %%
df[df['average_rating']==5.0]
# Out:
#        bookID                                              title  \
# 624      2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 786      2560                  Willem de Kooning: Late Paintings
# 855      2843  Literature Circle Guide: Bridge to Terabithia:...
# 1243     4287  Middlesex Borough (Images of America: New Jersey)
# 4125    14741  Zone of the Enders: The 2nd Runner Official St...
# 4788    17224  The Diamond Color Meditation: Color Pathway to...
# 4933    17830  Bulgakov's the Master and Margarita: The Text ...
# 5023    18184  The Complete Theory Fun Factory: Music Theory ...
# 5474    19786  The Goon Show  Volume 4: My Knees Have Fallen ...
# 5476    19788  The Goon Show  Volume 11: He's Fallen in the W...
# 5647    20954                                Winchester Shotguns
# 5648    20957  Colossians and Philemon: A Critical and Exeget...
# 6184    23276                          Taxation of Mineral Rents
# 6247    23552                        The New Big Book of America
# 4788                    3         2/1/2006            Square One Publishers
# 4933                    0         1/1/1975                    Vantage Press
# 5023                    0         6/1/2004              Boosey & Hawkes Inc
# 5474                    0         4/1/1996               BBC Physical Audio
# 5476                    0        10/2/1995               BBC Physical Audio
# 5647                    0        5/15/2008                  Chartwell Books
# 5648                    0        12/7/2005                  T&T Clark Int'l
# 6184                    0       11/17/1983     Oxford University Press  USA
# 6247                    1        3/21/2002                    Courage Books
# 6775                    0        6/22/1987                          Y Lolfa
# 8544                    1        6/17/2003                        Zondervan
# 9282                    1        2/28/2007  University Press of New England
# 9324                    1         2/1/2003                     Disney Press
# 9720                    0        7/25/2003                  Academica Press
# 9847                    0         5/1/2000       Texas A&M University Press
# 9893                    0       10/16/2007                        Multnomah
# 10262                   0        11/1/2001                         Raintree

# %%
df[df['average_rating']==5.0]
plt.figure(figsize=(30,12))
sns.barplot(most_rated['average_rating'], most_rated.index, palette = 'rocket')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat)
#     229                 # Perhaps a named matplotlib colormap?
# --> 230                 palette = mpl_palette(palette, n_colors)
#     231             except ValueError:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/palettes.py in mpl_palette(name, n_colors)
#     453     else:
# --> 454         cmap = mpl.cm.get_cmap(name)
#     455         if cmap is None:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cm.py in get_cmap(name, lut)
#     133         return name
# --> 134     cbook._check_in_list(sorted(cmap_d), name=name)
#     135     if lut is None:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _check_in_list(_values, **kwargs)
#    2142         if v not in values:
# -> 2143             raise ValueError(
#    2144                 "{!r} is not a valid value for {}; supported values are {}"
#
# ValueError: 'green' is not a valid value for name; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-b7f73852d7af> in <module>
#       1 df[df['average_rating']==5.0]
#       2 plt.figure(figsize=(30,12))
# ----> 3 sns.barplot(most_rated['average_rating'], most_rated.index, palette = 'green')
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1602         self.establish_variables(x, y, hue, data, orient,
#    1603                                  order, hue_order, units)
# -> 1604         self.establish_colors(color, palette, saturation)
#    1605         self.estimate_statistic(estimator, ci, n_boot, seed)
#    1606
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/categorical.py in establish_colors(self, color, palette, saturation)
#     303                 palette = [palette[l] for l in levels]
#     304
# --> 305             colors = color_palette(palette, n_colors)
#     306
#     307         # Desaturate a bit because these are patches
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat)
#     230                 palette = mpl_palette(palette, n_colors)
#     231             except ValueError:
# --> 232                 raise ValueError("%s is not a valid palette name" % palette)
#     233
#     234     if desat is not None:
#
# ValueError: green is not a valid palette name

# %% [markdown]
# # ¿Qué libro tiene mayor número de reviews con mejor puntuación?

# %% [markdown]
# # Mostrar las soluciones con gráficos

# %%
text_reviews_count = df.sort_values('text_reviews_count', ascending = False)
plt.figure(figsize=(30,12))
sns.barplot(most_rated['text_reviews_count'], most_rated.index, palette = 'rocket')
